# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12,5
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('EDA_Practice_Dataset_2_Telemarketingtopic_added1627027202s_p1515805800.csv')

# %%
df.head()
# Out:
#    Call_ID   Sale Agent_ID  Age  Product_ID  Timezone  Phone_code First_Name  \
# 0  9545434  False     5265   42         147         2        37.0         Jk
# 1  9211206  False     5226   74         146         2        37.0         Em
# 2  8873010  False     4452   35         144         2        37.0         BI
# 3  9852034  False     5461   40         149         2        37.0         WT
# 4  9416548  False     5298   26         147         2        37.0         LA
#
#   Last_Name Area_Code  Gender  Call_Count
# 0        Jk      2302    Male           1
# 1        Sh      1501    Male          10
# 2        MI      1550    Male           9
# 3        LI      1401    Male           6
# 4        LA       125  Female          12

# %%
df.shape
# Out:
# (100000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Call_ID     100000 non-null  int64
#  1   Sale        99968 non-null   object
#  2   Agent_ID    97685 non-null   object
#  3   Age         100000 non-null  int64
#  4   Product_ID  100000 non-null  int64
#  5   Timezone    100000 non-null  int64
#  6   Phone_code  99972 non-null   float64
#  7   First_Name  99318 non-null   object
#  8   Last_Name   99319 non-null   object
#  9   Area_Code   99540 non-null   object
#  10  Gender      100000 non-null  object
#  11  Call_Count  100000 non-null  int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 9.2+ MB

# %%
df.isna().sum()
# Out:
# Call_ID          0
# Sale            32
# Agent_ID      2315
# Age              0
# Product_ID       0
# Timezone         0
# Phone_code      28
# First_Name     682
# Last_Name      681
# Area_Code      460
# Gender           0
# Call_Count       0
# dtype: int64

# %%
df.Call_ID = df.Call_ID.astype('O')

# %%
df.Product_ID = df.Product_ID.astype('O')

# %%
df.Timezone = df.Timezone.astype('O')

# %% [markdown]
# ## Data Cleaning

# %%
df.Sale.unique()
# Out:
# array([False, True, nan], dtype=object)

# %%
df.Sale.value_counts()
# Out:
# False    91248
# True      8720
# Name: Sale, dtype: int64

# %%
df.Sale.fillna(False,inplace=True)

# %%
df.Sale.value_counts()
# Out:
# False    91280
# True      8720
# Name: Sale, dtype: int64

# %%
df.Agent_ID.unique()
# Out:
# array(['5265', '5226', '4452', '5461', '5298', '5139', '4828', '5292',
#        '5044', '4912', '5230', '5002', '5053', '5312', '5214', '4926',
#        '5425', '5077', '5357', '4722', '5076', '4994', '5051', '5472',
#        '5296', '5207', '5386', '5209', '5208', '4866', nan, '5297',
#        '4995', '5313', '4958', '5073', '5028', '4804', '5341', '4876',
#        '5382', '5405', '5146', '5181', '4702', '5272', '4894', '5065',
#        '5403', '5459', '5424', '4971', '4677', '4748', '4899', '5266',
#        '5035', '5460', '4968', '4865', '5252', '5399', '5061', '4706',
#        '4955', '5220', '4956', '5216', '5032', '5406', '5224', '5462',
#        '4121', '5271', '5407', '5206', '5001', '5005', '5287', '5396',
#        '5464', '5294', '5052', '5423', '5421', '4827', '4483', '4709',
#        '5384', '5416', '5089', '5429', '5428', '5245', '5401', '4970',
#        '5366', '5381', '5367', '5302', '5368', '5106', '5495', '5393',
# ...

# %%
df= df.replace({'Agent_ID': '[A-Za-a]'}, '', regex=True)

# %%
df.Agent_ID.unique()
# Out:
# array(['5265', '5226', '4452', '5461', '5298', '5139', '4828', '5292',
#        '5044', '4912', '5230', '5002', '5053', '5312', '5214', '4926',
#        '5425', '5077', '5357', '4722', '5076', '4994', '5051', '5472',
#        '5296', '5207', '5386', '5209', '5208', '4866', nan, '5297',
#        '4995', '5313', '4958', '5073', '5028', '4804', '5341', '4876',
#        '5382', '5405', '5146', '5181', '4702', '5272', '4894', '5065',
#        '5403', '5459', '5424', '4971', '4677', '4748', '4899', '5266',
#        '5035', '5460', '4968', '4865', '5252', '5399', '5061', '4706',
#        '4955', '5220', '4956', '5216', '5032', '5406', '5224', '5462',
#        '4121', '5271', '5407', '5206', '5001', '5005', '5287', '5396',
#        '5464', '5294', '5052', '5423', '5421', '4827', '4483', '4709',
#        '5384', '5416', '5089', '5429', '5428', '5245', '5401', '4970',
#        '5366', '5381', '5367', '5302', '5368', '5106', '5495', '5393',
# ...

# %%
df.Agent_ID.mode()
# Out:
# 0    4955
# dtype: object

# %%
df.Agent_ID.fillna('4955', inplace=True)

# %%
df.isna().sum()
# Out:
# Call_ID         0
# Sale            0
# Agent_ID        0
# Age             0
# Product_ID      0
# Timezone        0
# Phone_code     28
# First_Name    682
# Last_Name     681
# Area_Code     460
# Gender          0
# Call_Count      0
# dtype: int64

# %%
df.Phone_code.unique()
# Out:
# array([37., nan])

# %%
df.Phone_code.fillna('37', inplace=True)

# %%
df.isna().sum()
# Out:
# Call_ID         0
# Sale            0
# Agent_ID        0
# Age             0
# Product_ID      0
# Timezone        0
# Phone_code      0
# First_Name    682
# Last_Name     681
# Area_Code     460
# Gender          0
# Call_Count      0
# dtype: int64

# %% [markdown]
# Record without first name and last names are just insignificant

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Call_ID       0
# Sale          0
# Agent_ID      0
# Age           0
# Product_ID    0
# Timezone      0
# Phone_code    0
# First_Name    0
# Last_Name     0
# Area_Code     0
# Gender        0
# Call_Count    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98410 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Call_ID     98410 non-null  object
#  1   Sale        98410 non-null  bool
#  2   Agent_ID    98410 non-null  object
#  3   Age         98410 non-null  int64
#  4   Product_ID  98410 non-null  object
#  5   Timezone    98410 non-null  int64
#  6   Phone_code  98410 non-null  object
#  7   First_Name  98410 non-null  object
#  8   Last_Name   98410 non-null  object
#  9   Area_Code   98410 non-null  object
#  10  Gender      98410 non-null  object
#  11  Call_Count  98410 non-null  int64
# dtypes: bool(1), int64(3), object(8)
# memory usage: 11.1+ MB

# %% [markdown]
# ### Age

# %%
plt.hist(df.Age)
plt.title("Age Distribution", size=20)
plt.xlabel('Age')
plt.ylabel('Counts');

# %%
df.Age.skew()  ## very close to zero slightly left skewed
# Out:
# -0.0033784135293702332

# %% [markdown]
# ### Age vs Call Count

# %%
sns.scatterplot(x='Age', y='Call_Count', data=df, hue='Gender');

# %%
sns.boxplot(x='Age', y='Call_Count', data=df);

# %%
sns.scatterplot(x='Age', y='Call_Count', data=df, hue='Sale');

# %% [markdown]
# ### Age vs Timezone

# %%
sns.scatterplot(x='Age', y='Timezone', data=df);

# %% [markdown]
# ## Product_ID

# %%
df.Product_ID.skew()
# Out:
# -0.23808536477960154

# %% [markdown]
# ### Product_ID vs Sale

# %%
sns.countplot(df.Product_ID,hue=df.Sale);

# %%
sns.catplot(x= 'Product_ID', y='Age', data=df, hue='Sale', col='Gender', kind='bar', height=7, ci= None)

# %%
sns.boxplot(x='Product_ID', y='Call_Count', data=df);

# %% [markdown]
# ## Gender

# %%
sns.countplot(df.Gender,hue=df.Sale);

# %%
sns.countplot(df.Gender,hue=df.Product_ID,);

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(),annot=True)
plt.show()
